# %% [markdown]
# # Homework 4 - Alberto Trashaj
# Download the Nile data, available in the R dataset: and fit a LLM to the data. Compare your results with Table 2.1.

# %% [markdown]
# ### Import libraries
# As usual we import the libraries needed to deal with algebra calculation and to plot the result.

# %%
import numpy as np
from scipy.optimize import minimize 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Functions
# Now, as we did in the Lab, we will define the function of the Kalman filter, the likelihood and the estimator function.

# %% [markdown]
# ## Kalman filter

# %%
np.random.seed(0)

def KF(y, q):
    m20 = y[0]
    P20 = 1 + q

    n = len(y)
    mu_pred = np.empty(n)
    P = np.zeros(n)
    v = np.empty(n)
    K = np.zeros(n)
    F = np.zeros(n)
    dllk = np.empty(n)
    llk = 0

    mu_pred[1] = m20
    P[1] = P20


    for t in range(1, n-1):
        v[t] = y[t] - mu_pred[t]
        F[t] = P[t] + 1
        K[t] = P[t] / F[t]
        P[t + 1] = P[t] * (1 - K[t]) + q
        mu_pred[t + 1] = mu_pred[t] + K[t] * v[t]
        dllk[t] = -0.5 * np.log(F[t])

        print("Iteration:", t)
        print("Likelihood:", -0.5 * np.log(F[t]))
        print("Score:", -K[t])
        print("Signal-to-Noise Ratio (q):", q)
        print()

    #Since we need to define sigma_e_hat and the likelihood 
    # we need the last element computed in the for loop, so we retrieve those values below

    F[n - 1] = P[n - 1] + 1
    K[n - 1] = P[n - 1] / F[n - 1]
    dllk[n - 1] = -0.5 * np.log(F[n - 1])
    v[n - 1] = y[n - 1] - mu_pred[n - 1]

    sigma_e_hat = np.sum(v[1:] ** 2 / F[1:]) / (n - 1)
    llk = -0.5 * (n - 1) * np.log(sigma_e_hat) + np.sum(dllk[1:])

    return {'mu_pred': mu_pred, 'llk': llk, 'v': v, 'F': F}

# %% [markdown]
# ## Loglikelihood

# %%
def loglikelihood(par, y):
    q_new = par[0]
    obj = KF(y, q_new)['llk']
    return -obj

# %% [markdown]
# ## Estimator

# %% [markdown]
# Here a mention has to be done with the function minimize: in the book, they used the 'BFGS' algorithm, although to get the most similar result to the table I used the 'Nelder-Mead' method just to be consistent with the table 2.1.
# If in the method argument we put 'BFGS' the algorithm converges but not with the same result of the table.

# %%
#This uses the Nelder-Mead method
def estimator(y, par):
    n = len(y)
    q_0 = par

    hat = minimize(loglikelihood, q_0, args=(y,), method='Nelder-Mead') #here the method used is the Nelder-Mead although in the book they use BFGS 

    q_hat = hat.x[0]
    theta_list = {'q_hat': q_hat, 'iter': hat.nit}
    out = {'theta_list': theta_list}
    return out

# %%
##This uses the BFGS method
def estimator_bfgs(y, par):
    n = len(y)
    q_0 = par

    hat = minimize(loglikelihood, q_0, args=(y,), method='BFGS') #here the method used is the Nelder-Mead although in the book they use BFGS 

    q_hat = hat.x[0]
    theta_list = {'q_hat': q_hat, 'iter': hat.nit}
    out = {'theta_list': theta_list}
    return out

# %%
#Load the dataset

# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context
# uncomment those lines above if you get an  URL error message


from statsmodels.datasets import get_rdataset
data = get_rdataset('Nile').data

#data = pd.read_csv("/Users/albertotrashaj/Desktop/Advanced-time-series-github/Assignement 4/Nile.csv")
y = np.array(data['value'])
n = len(y)

q_0 = 1
est = estimator(y, q_0)

#est = estimator_bfgs(y, q_0) uncomment this line and comment the above one to get the result with the BFGS algorithm

q_hat = est['theta_list']['q_hat']

filter_output = KF(y, q_hat)
sigma_e_hat = np.sum(filter_output['v'][1:] ** 2 / filter_output['F'][1:]) / (n - 1)
sigma_eta_hat = q_hat * sigma_e_hat


print("The value of sigma_e_hat is ", sigma_e_hat)
print("The value of sigma_eta_hat is ", sigma_eta_hat)
# Out:
# Iteration: 1
# Likelihood: -0.5493061443340549
# Score: -0.6666666666666666
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 2
# Likelihood: -0.49041462650586315
# Score: -0.625
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 3
# Likelihood: -0.4825404480217935
# Score: -0.6190476190476191
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 4
# Likelihood: -0.48140537375452397
# Score: -0.6181818181818182
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 5
# Likelihood: -0.4812400571717648
# Score: -0.6180555555555556
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 6
# Likelihood: -0.48121594393600503
# Score: -0.6180371352785146
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 7
# Likelihood: -0.48121242599273545
# Score: -0.6180344478216818
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 8
# Likelihood: -0.4812119127345054
# Score: -0.6180340557275542
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 9
# Likelihood: -0.481211837851198
# Score: -0.6180339985218034
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 10
# Likelihood: -0.48121182692587194
# Score: -0.6180339901755971
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 11
# Likelihood: -0.48121182533188833
# Score: -0.618033988957902
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 12
# Likelihood: -0.48121182509932925
# Score: -0.6180339887802427
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 13
# Likelihood: -0.48121182506539933
# Score: -0.6180339887543226
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 14
# Likelihood: -0.48121182506044907
# Score: -0.6180339887505408
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 15
# Likelihood: -0.48121182505972676
# Score: -0.6180339887499892
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 16
# Likelihood: -0.48121182505962146
# Score: -0.6180339887499086
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 17
# Likelihood: -0.4812118250596061
# Score: -0.6180339887498969
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 18
# Likelihood: -0.4812118250596038
# Score: -0.6180339887498951
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 19
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 20
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 21
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 22
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 23
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 24
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 25
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 26
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 27
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 28
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 29
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 30
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 31
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 32
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 33
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 34
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 35
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 36
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 37
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 38
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 39
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 40
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 41
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 42
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 43
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 44
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 45
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 46
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 47
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 48
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 49
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 50
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 51
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 52
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 53
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 54
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 55
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 56
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 57
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 58
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 59
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 60
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 61
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 62
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 63
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 64
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 65
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 66
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 67
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 68
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 69
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 70
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 71
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 72
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 73
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 74
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 75
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 76
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 77
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 78
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 79
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 80
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 81
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 82
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 83
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 84
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 85
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 86
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 87
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 88
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 89
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 90
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 91
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 92
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 93
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 94
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 95
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 96
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 97
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 98
# Likelihood: -0.48121182505960347
# Score: -0.6180339887498949
# Signal-to-Noise Ratio (q): 1.0
#
# Iteration: 1
# Likelihood: -0.5575707953096601
# Score: -0.6721311475409836
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 2
# Likelihood: -0.5007075418247221
# Score: -0.632640770852153
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 3
# Likelihood: -0.4934008358151573
# Score: -0.6272329821922652
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 4
# Likelihood: -0.4923918959139542
# Score: -0.6264800237216765
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 5
# Likelihood: -0.4922512536205176
# Score: -0.6263749435314341
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 6
# Likelihood: -0.49223162293915246
# Score: -0.6263602742146002
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 7
# Likelihood: -0.4922288824118823
# Score: -0.6263582262692723
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 8
# Likelihood: -0.4922284998127735
# Score: -0.6263579403591436
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 9
# Likelihood: -0.492228446398746
# Score: -0.626357900443687
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 10
# Likelihood: -0.49222843894169843
# Score: -0.6263578948711531
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 11
# Likelihood: -0.49222843790063175
# Score: -0.6263578940931804
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 12
# Likelihood: -0.49222843775529007
# Score: -0.626357893984569
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 13
# Likelihood: -0.4922284377349992
# Score: -0.6263578939694059
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 14
# Likelihood: -0.4922284377321664
# Score: -0.6263578939672889
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 15
# Likelihood: -0.4922284377317709
# Score: -0.6263578939669934
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 16
# Likelihood: -0.49222843773171576
# Score: -0.6263578939669522
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 17
# Likelihood: -0.49222843773170805
# Score: -0.6263578939669464
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 18
# Likelihood: -0.49222843773170694
# Score: -0.6263578939669456
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 19
# Likelihood: -0.49222843773170677
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 20
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 21
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 22
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 23
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 24
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 25
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 26
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 27
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 28
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 29
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 30
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 31
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 32
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 33
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 34
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 35
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 36
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 37
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 38
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 39
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 40
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 41
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 42
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 43
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 44
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 45
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 46
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 47
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 48
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 49
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 50
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 51
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 52
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 53
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 54
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 55
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 56
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 57
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 58
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 59
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 60
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 61
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 62
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 63
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 64
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 65
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 66
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 67
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 68
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 69
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 70
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 71
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 72
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 73
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 74
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 75
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 76
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 77
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 78
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 79
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 80
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 81
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 82
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 83
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 84
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 85
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 86
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 87
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 88
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 89
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 90
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 91
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 92
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 93
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 94
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 95
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 96
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 97
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669454
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 98
# Likelihood: -0.4922284377317067
# Score: -0.6263578939669455
# Signal-to-Noise Ratio (q): 1.05
#
# Iteration: 1
# Likelihood: -0.5409025851758642
# Score: -0.6610169491525423
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 2
# Likelihood: -0.4798698905684788
# Score: -0.617007465108731
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 3
# Likelihood: -0.4713704049955099
# Score: -0.6104413354490799
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 4
# Likelihood: -0.47008982014633566
# Score: -0.6094423308376216
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 5
# Likelihood: -0.4698946976222216
# Score: -0.6092898878980669
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 6
# Likelihood: -0.46986491623630694
# Score: -0.6092666154277289
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 7
# Likelihood: -0.4698603695500834
# Score: -0.6092630623273806
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 8
# Likelihood: -0.4698596753858269
# Score: -0.6092625198557724
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 9
# Likelihood: -0.469859569403821
# Score: -0.6092624370334798
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 10
# Likelihood: -0.46985955322293044
# Score: -0.609262424388516
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 11
# Likelihood: -0.4698595507524992
# Score: -0.6092624224579355
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 12
# Likelihood: -0.4698595503753239
# Score: -0.6092624221631824
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 13
# Likelihood: -0.46985955031773835
# Score: -0.6092624221181806
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 14
# Likelihood: -0.4698595503089465
# Score: -0.60926242211131
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 15
# Likelihood: -0.4698595503076041
# Score: -0.609262422110261
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 16
# Likelihood: -0.4698595503073992
# Score: -0.6092624221101008
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 17
# Likelihood: -0.469859550307368
# Score: -0.6092624221100764
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 18
# Likelihood: -0.4698595503073631
# Score: -0.6092624221100728
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 19
# Likelihood: -0.46985955030736243
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 20
# Likelihood: -0.4698595503073623
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 21
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 22
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 23
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 24
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 25
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 26
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 27
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 28
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 29
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 30
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 31
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 32
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 33
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 34
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 35
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 36
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 37
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 38
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 39
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 40
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 41
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 42
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 43
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 44
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 45
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 46
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 47
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 48
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 49
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 50
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 51
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 52
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 53
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 54
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 55
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 56
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 57
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 58
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 59
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 60
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 61
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 62
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 63
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 64
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 65
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 66
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 67
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 68
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 69
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 70
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 71
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 72
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 73
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 74
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 75
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 76
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 77
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 78
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 79
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 80
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 81
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 82
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 83
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 84
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 85
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 86
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 87
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 88
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 89
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 90
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 91
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 92
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 93
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 94
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 95
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 96
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 97
# Likelihood: -0.46985955030736226
# Score: -0.6092624221100721
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 98
# Likelihood: -0.46985955030736226
# Score: -0.609262422110072
# Signal-to-Noise Ratio (q): 0.95
#
# Iteration: 1
# Likelihood: -0.5323553684962141
# Score: -0.6551724137931034
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 2
# Likelihood: -0.4690598511577836
# Score: -0.6086369770580297
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 3
# Likelihood: -0.4598697843085057
# Score: -0.6013771585346173
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 4
# Likelihood: -0.4584207218092242
# Score: -0.6002202240521656
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 5
# Likelihood: -0.4581894088076792
# Score: -0.6000352327447074
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 6
# Likelihood: -0.45815241243636556
# Score: -0.6000056371597081
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 7
# Likelihood: -0.45814649336774804
# Score: -0.6000009019435195
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 8
# Likelihood: -0.4581455463257489
# Score: -0.6000001443109111
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 9
# Likelihood: -0.45814539479925886
# Score: -0.6000000230897444
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 10
# Likelihood: -0.45814537055502635
# Score: -0.600000003694359
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 11
# Likelihood: -0.45814536667594935
# Score: -0.6000000005910975
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 12
# Likelihood: -0.458145366055297
# Score: -0.6000000000945755
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 13
# Likelihood: -0.45814536595599265
# Score: -0.6000000000151321
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 14
# Likelihood: -0.4581453659401039
# Score: -0.6000000000024212
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 15
# Likelihood: -0.4581453659375618
# Score: -0.6000000000003873
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 16
# Likelihood: -0.458145365937155
# Score: -0.6000000000000619
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 17
# Likelihood: -0.45814536593709
# Score: -0.6000000000000099
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 18
# Likelihood: -0.4581453659370795
# Score: -0.6000000000000015
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 19
# Likelihood: -0.4581453659370779
# Score: -0.6000000000000002
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 20
# Likelihood: -0.45814536593707755
# Score: -0.6000000000000001
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 21
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 22
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 23
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 24
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 25
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 26
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 27
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 28
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 29
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 30
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 31
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 32
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 33
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 34
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 35
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 36
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 37
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 38
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 39
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 40
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 41
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 42
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 43
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 44
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 45
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 46
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 47
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 48
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 49
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 50
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 51
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 52
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 53
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 54
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 55
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 56
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 57
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 58
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 59
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 60
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 61
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 62
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 63
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 64
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 65
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 66
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 67
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 68
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 69
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 70
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 71
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 72
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 73
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 74
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 75
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 76
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 77
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 78
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 79
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 80
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 81
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 82
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 83
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 84
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 85
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 86
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 87
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 88
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 89
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 90
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 91
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 92
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 93
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 94
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 95
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 96
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 97
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 98
# Likelihood: -0.45814536593707755
# Score: -0.6
# Signal-to-Noise Ratio (q): 0.8999999999999999
#
# Iteration: 1
# Likelihood: -0.5148097085905791
# Score: -0.6428571428571428
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 2
# Likelihood: -0.4465841572266504
# Score: -0.5906432748538011
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 3
# Likelihood: -0.4357812411934174
# Score: -0.581702544031311
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 4
# Likelihood: -0.43390779328710943
# Score: -0.5801322870876299
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 5
# Likelihood: -0.43357803447432236
# Score: -0.5798552855969124
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 6
# Likelihood: -0.4335198407318387
# Score: -0.5798063831645203
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 7
# Likelihood: -0.4335095663813076
# Score: -0.5797977486427861
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 8
# Likelihood: -0.43350775225528054
# Score: -0.5797962240403385
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 9
# Likelihood: -0.43350743193332525
# Score: -0.579795954839262
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 10
# Likelihood: -0.4335073753736315
# Score: -0.579795907306035
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 11
# Likelihood: -0.43350736538680307
# Score: -0.5797958989130226
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 12
# Likelihood: -0.433507363623414
# Score: -0.579795897431056
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 13
# Likelihood: -0.43350736331204975
# Score: -0.579795897169383
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 14
# Likelihood: -0.43350736325707173
# Score: -0.5797958971231789
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 15
# Likelihood: -0.43350736324736416
# Score: -0.5797958971150206
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 16
# Likelihood: -0.4335073632456501
# Score: -0.5797958971135801
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 17
# Likelihood: -0.43350736324534744
# Score: -0.5797958971133258
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 18
# Likelihood: -0.43350736324529393
# Score: -0.5797958971132808
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 19
# Likelihood: -0.43350736324528455
# Score: -0.579795897113273
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 20
# Likelihood: -0.43350736324528283
# Score: -0.5797958971132715
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 21
# Likelihood: -0.43350736324528255
# Score: -0.5797958971132713
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 22
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 23
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 24
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 25
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 26
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 27
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 28
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 29
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 30
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 31
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 32
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 33
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 34
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 35
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 36
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 37
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 38
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 39
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 40
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 41
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 42
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 43
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 44
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 45
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 46
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 47
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 48
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 49
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 50
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 51
# Likelihood: -0.4335073632452825
# Score: -0.5797958971132712
# Signal-to-Noise Ratio (q): 0.7999999999999998
#
# Iteration: 52
# Likelihood: -0.4335073632452825
# ...
#
# Iteration: 70
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 71
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 72
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 73
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 74
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 75
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 76
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 77
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 78
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 79
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 80
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 81
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 82
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 83
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 84
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 85
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 86
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 87
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 88
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 89
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 90
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 91
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 92
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 93
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 94
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 95
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 96
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 97
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 98
# Likelihood: -0.15538935879364724
# Score: -0.2671239694960697
# Signal-to-Noise Ratio (q): 0.09736328124999918
#
# Iteration: 1
# Likelihood: -0.3703172064744805
# Score: -0.5231886757310484
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 2
# Likelihood: -0.24135327124023218
# Score: -0.3828891073639889
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 3
# Likelihood: -0.19607331560287772
# Score: -0.3243949580846337
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 4
# Likelihood: -0.17591280653810043
# Score: -0.2965972244723416
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 5
# Likelihood: -0.16603946058990873
# Score: -0.28256929985718543
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 6
# Likelihood: -0.16098193617270168
# Score: -0.2752756275512437
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 7
# Likelihood: -0.15833197522674938
# Score: -0.27142444852478803
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 8
# Likelihood: -0.15692706586225982
# Score: -0.2693744045175251
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 9
# Likelihood: -0.1561775971276374
# Score: -0.26827842123647005
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 10
# Likelihood: -0.1557764589504675
# Score: -0.26769114276755346
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 11
# Likelihood: -0.15556137808509646
# Score: -0.26737606375948125
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 12
# Likelihood: -0.15544594755035301
# Score: -0.2672069098892588
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 13
# Likelihood: -0.155383966315206
# Score: -0.267116065417058
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 14
# Likelihood: -0.15535067597987337
# Score: -0.26706726788870555
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 15
# Likelihood: -0.15533279300718872
# Score: -0.267041053387859
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 16
# Likelihood: -0.1553231858384284
# Score: -0.26702696993196834
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 17
# Likelihood: -0.15531802441511916
# Score: -0.2670194035247502
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 18
# Likelihood: -0.15531525139259156
# Score: -0.26701533837006475
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 19
# Likelihood: -0.15531376154235607
# Score: -0.2670131542920694
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 20
# Likelihood: -0.15531296109149506
# Score: -0.26701198085122657
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 21
# Likelihood: -0.15531253103227066
# Score: -0.26701135039443735
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 22
# Likelihood: -0.155312299973382
# Score: -0.26701101166727353
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 23
# Likelihood: -0.155312175831726
# Score: -0.2670108296783173
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 24
# Likelihood: -0.15531210913375457
# Score: -0.2670107319005292
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 25
# Likelihood: -0.15531207329871863
# Score: -0.2670106793671338
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 26
# Likelihood: -0.15531205404550935
# Score: -0.2670106511423397
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 27
# Likelihood: -0.15531204370127244
# Score: -0.2670106359779087
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 28
# Likelihood: -0.1553120381435891
# Score: -0.2670106278304631
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 29
# Likelihood: -0.15531203515759356
# Score: -0.2670106234530571
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 30
# Likelihood: -0.1553120335532975
# Score: -0.26701062110119317
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 31
# Likelihood: -0.1553120326913519
# Score: -0.26701061983759916
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 32
# Likelihood: -0.15531203222825146
# Score: -0.26701061915870367
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 33
# Likelihood: -0.15531203197943982
# Score: -0.2670106187939512
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 34
# Likelihood: -0.15531203184575998
# Score: -0.26701061859797937
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 35
# Likelihood: -0.15531203177393732
# Score: -0.2670106184926889
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 36
# Likelihood: -0.15531203173534894
# Score: -0.2670106184361191
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 37
# Likelihood: -0.15531203171461638
# Score: -0.26701061840572565
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 38
# Likelihood: -0.15531203170347735
# Score: -0.2670106183893961
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 39
# Likelihood: -0.1553120316974927
# Score: -0.2670106183806226
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 40
# Likelihood: -0.1553120316942772
# Score: -0.2670106183759089
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 41
# Likelihood: -0.1553120316925497
# Score: -0.2670106183733763
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 42
# Likelihood: -0.1553120316916215
# Score: -0.2670106183720157
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 43
# Likelihood: -0.15531203169112281
# Score: -0.2670106183712846
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 44
# Likelihood: -0.15531203169085492
# Score: -0.2670106183708918
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 45
# Likelihood: -0.15531203169071098
# Score: -0.2670106183706808
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 46
# Likelihood: -0.1553120316906336
# Score: -0.26701061837056744
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 47
# Likelihood: -0.15531203169059207
# Score: -0.2670106183705065
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 48
# Likelihood: -0.15531203169056979
# Score: -0.26701061837047374
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 49
# Likelihood: -0.15531203169055774
# Score: -0.2670106183704562
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 50
# Likelihood: -0.1553120316905513
# Score: -0.26701061837044676
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 51
# Likelihood: -0.1553120316905478
# Score: -0.26701061837044165
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 52
# Likelihood: -0.15531203169054594
# Score: -0.26701061837043893
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 53
# Likelihood: -0.15531203169054497
# Score: -0.26701061837043744
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 54
# Likelihood: -0.1553120316905444
# Score: -0.26701061837043666
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 55
# Likelihood: -0.15531203169054414
# Score: -0.26701061837043627
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 56
# Likelihood: -0.15531203169054397
# Score: -0.267010618370436
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 57
# Likelihood: -0.15531203169054392
# Score: -0.26701061837043594
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 58
# Likelihood: -0.15531203169054392
# Score: -0.2670106183704358
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 59
# Likelihood: -0.15531203169054392
# Score: -0.2670106183704358
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 60
# Likelihood: -0.15531203169054383
# Score: -0.2670106183704358
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 61
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 62
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 63
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 64
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 65
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 66
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 67
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 68
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 69
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 70
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 71
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 72
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 73
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 74
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 75
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 76
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 77
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 78
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 79
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 80
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 81
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 82
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 83
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 84
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 85
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 86
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 87
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 88
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 89
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 90
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 91
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 92
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 93
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 94
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 95
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 96
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 97
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# Iteration: 98
# Likelihood: -0.15531203169054383
# Score: -0.26701061837043577
# Signal-to-Noise Ratio (q): 0.09726562499999919
#
# The value of sigma_e_hat is  15099.46118346705
# The value of sigma_eta_hat is  1468.65852917315
# /var/folders/4z/ffhfh8nj0zz1mqdx8xrwbjfr0000gn/T/ipykernel_34264/225816577.py:26: RuntimeWarning: invalid value encountered in log
#   dllk[t] = -0.5 * np.log(F[t])
# /var/folders/4z/ffhfh8nj0zz1mqdx8xrwbjfr0000gn/T/ipykernel_34264/225816577.py:29: RuntimeWarning: invalid value encountered in log
#   print("Likelihood:", -0.5 * np.log(F[t]))
